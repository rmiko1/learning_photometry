# %% [markdown]
# Connected to PAML1 (Python 3.12.8)

# %%
# 2/21/25 Photometry Analysis Code (read raw file and graph)

import pandas as pd

filepath_415 = "C:\\Users\\rache\\Desktop\\test_415_2025-02-18T11_35_22.csv"

filepath_470 = "C:\\Users\\rache\\Desktop\\test_470_2025-02-18T11_35_22.csv"


def read_file(filepath_415, filepath_470):
    pd_415 = pd.read_csv(filepath_415)
    pd_470 = pd.read_csv(filepath_470)

    print(pd_415.head())

    print(pd_470.head())


    return

# %%
filepath_415 = "C:\\Users\\rache\\Desktop\\test_415_2025-02-18T11_35_22.csv"

# %%
    pd_415 = pd.read_csv(filepath_415)

# %%
    print(pd_415.head())
# Out:
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             2  3107.800544         1            0        1        0       0
# 2             4  3107.820544         1            0        1        0       0
# 3             6  3107.840544         1            0        1        0       0
# 4             8  3107.860544         1            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.055598
# 2       0  0.054875
# 3       0  0.052332
# 4       0  0.051890

# %%
# 2/21/25 Photometry Analysis Code (read raw file and graph)

import pandas as pd

filepath_415 = "C:\\Users\\rache\\Desktop\\test_415_2025-02-18T11_35_22.csv"

filepath_470 = "C:\\Users\\rache\\Desktop\\test_470_2025-02-18T11_35_22.csv"


def read_file(filepath_415, filepath_470):
    pd_415 = pd.read_csv(filepath_415)
    pd_470 = pd.read_csv(filepath_470)

    print(pd_415.head())

    print(pd_470.head())


    return 


read_file(filepath_415, filepath_470)
# Out:
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             2  3107.800544         1            0        1        0       0
# 2             4  3107.820544         1            0        1        0       0
# 3             6  3107.840544         1            0        1        0       0
# 4             8  3107.860544         1            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.055598
# 2       0  0.054875
# 3       0  0.052332
# 4       0  0.051890
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             1  3107.790560         2            0        1        0       0
# 2             3  3107.810560         2            0        1        0       0
# 3             5  3107.830560         2            0        1        0       0
# 4             7  3107.850560         2            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.038322
# 2       0  0.039498
# 3       0  0.037089
# 4       0  0.036743

# %%
# 2/21/25 Photometry Analysis Code (read raw file and graph)

import pandas as pd

filepath_415 = "C:\\Users\\rache\\Desktop\\test_415_2025-02-18T11_35_22.csv"

filepath_470 = "C:\\Users\\rache\\Desktop\\test_470_2025-02-18T11_35_22.csv"


def read_file(filepath_415, filepath_470):
    pd_415 = pd.read_csv(filepath_415)
    pd_470 = pd.read_csv(filepath_470)

    print(pd_415.head())

    print(pd_470.head())

    pd_415_clean = pd_415['FrameCounter', 'Timestamp']

    print(pd_415_clean.head())


    return 


read_file(filepath_415, filepath_470)
# Out:
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             2  3107.800544         1            0        1        0       0
# 2             4  3107.820544         1            0        1        0       0
# 3             6  3107.840544         1            0        1        0       0
# 4             8  3107.860544         1            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.055598
# 2       0  0.054875
# 3       0  0.052332
# 4       0  0.051890
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             1  3107.790560         2            0        1        0       0
# 2             3  3107.810560         2            0        1        0       0
# 3             5  3107.830560         2            0        1        0       0
# 4             7  3107.850560         2            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.038322
# 2       0  0.039498
# 3       0  0.037089
# 4       0  0.036743
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('FrameCounter', 'Timestamp')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rache\Documents\Untitled-1.py:26
#      20     print(pd_415_clean.head())
#      23     return
# ---> 26 read_file(filepath_415, filepath_470)
#
# File c:\Users\rache\Documents\Untitled-1.py:18
#      14 print(pd_415.head())
#      16 print(pd_470.head())
# ---> 18 pd_415_clean = pd_415['FrameCounter', 'Timestamp']
#      20 print(pd_415_clean.head())
#      23 return
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ('FrameCounter', 'Timestamp')

# %%
pd_415_clean = pd_415['FrameCounter', 'Timestamp']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('FrameCounter', 'Timestamp')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd_415_clean = pd_415['FrameCounter', 'Timestamp']
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ('FrameCounter', 'Timestamp')

# %%
pd_415_clean = pd_415['FrameCounter']

# %%
pd_415_clean = pd_415[('FrameCounter', 'Timestamp')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('FrameCounter', 'Timestamp')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd_415_clean = pd_415[('FrameCounter', 'Timestamp')]
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ('FrameCounter', 'Timestamp')

# %%
pd_415_clean = pd_415[['FrameCounter', 'Timestamp']]

# %%
# 2/21/25 Photometry Analysis Code (read raw file and graph)

import pandas as pd

filepath_415 = "C:\\Users\\rache\\Desktop\\test_415_2025-02-18T11_35_22.csv"

filepath_470 = "C:\\Users\\rache\\Desktop\\test_470_2025-02-18T11_35_22.csv"


def read_file(filepath_415, filepath_470):
    pd_415 = pd.read_csv(filepath_415)
    pd_470 = pd.read_csv(filepath_470)

    print(pd_415.head())

    print(pd_470.head())

    pd_415_clean = pd_415[['FrameCounter', 'Timestamp']]
    pd_470_clean = pd_470[['FrameCounter', 'Timestamp']]


    print(pd_415_clean.head())
    print(pd_470_clean.head())


    return 


read_file(filepath_415, filepath_470)
# Out:
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             2  3107.800544         1            0        1        0       0
# 2             4  3107.820544         1            0        1        0       0
# 3             6  3107.840544         1            0        1        0       0
# 4             8  3107.860544         1            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.055598
# 2       0  0.054875
# 3       0  0.052332
# 4       0  0.051890
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             1  3107.790560         2            0        1        0       0
# 2             3  3107.810560         2            0        1        0       0
# 3             5  3107.830560         2            0        1        0       0
# 4             7  3107.850560         2            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.038322
# 2       0  0.039498
# 3       0  0.037089
# 4       0  0.036743
#    FrameCounter    Timestamp
# 0             0  3107.780576
# 1             2  3107.800544
# 2             4  3107.820544
# 3             6  3107.840544
# 4             8  3107.860544
#    FrameCounter    Timestamp
# 0             0  3107.780576
# 1             1  3107.790560
# 2             3  3107.810560
# 3             5  3107.830560
# 4             7  3107.850560

# %%
import matplotlib as plt

# %%
pd_470_clean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd_470_clean
#
# NameError: name 'pd_470_clean' is not defined

# %%
pd_415 = pd.read_csv(filepath_415)
    pd_470 = pd.read_csv(filepath_470)

    print(pd_415.head())

    print(pd_470.head())

    pd_415_clean = pd_415[['FrameCounter', 'Timestamp']]
    pd_470_clean = pd_470[['FrameCounter', 'Timestamp']]


    print(pd_415_clean.head())
    print(pd_470_clean.head())
# Out:
#   Cell In[14], line 2
#     pd_470 = pd.read_csv(filepath_470)
#     ^
# IndentationError: unexpected indent

# %%
pd_415 = pd.read_csv(filepath_415)
pd_470 = pd.read_csv(filepath_470)

print(pd_415.head())

print(pd_470.head())

pd_415_clean = pd_415[['FrameCounter', 'Timestamp']]
pd_470_clean = pd_470[['FrameCounter', 'Timestamp']]


print(pd_415_clean.head())
print(pd_470_clean.head())
# Out:
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             2  3107.800544         1            0        1        0       0
# 2             4  3107.820544         1            0        1        0       0
# 3             6  3107.840544         1            0        1        0       0
# 4             8  3107.860544         1            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.055598
# 2       0  0.054875
# 3       0  0.052332
# 4       0  0.051890
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             1  3107.790560         2            0        1        0       0
# 2             3  3107.810560         2            0        1        0       0
# 3             5  3107.830560         2            0        1        0       0
# 4             7  3107.850560         2            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.038322
# 2       0  0.039498
# 3       0  0.037089
# 4       0  0.036743
#    FrameCounter    Timestamp
# 0             0  3107.780576
# 1             2  3107.800544
# 2             4  3107.820544
# 3             6  3107.840544
# 4             8  3107.860544
#    FrameCounter    Timestamp
# 0             0  3107.780576
# 1             1  3107.790560
# 2             3  3107.810560
# 3             5  3107.830560
# 4             7  3107.850560

# %%
pd_470_clean
# Out:
#        FrameCounter    Timestamp
# 0                 0  3107.780576
# 1                 1  3107.790560
# 2                 3  3107.810560
# 3                 5  3107.830560
# 4                 7  3107.850560
# ...             ...          ...
# 43514         87027  3978.048288
# 43515         87029  3978.068288
# 43516         87031  3978.088288
# 43517         87033  3978.108288
# 43518         87035  3978.128288
#
# [43519 rows x 2 columns]

# %%
plt.plot(pd_470_clean)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.plot(pd_470_clean)
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
import matplotlib as plt

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(pd_470_clean)
# Out:
# [<matplotlib.lines.Line2D at 0x22800baecc0>,
#  <matplotlib.lines.Line2D at 0x22800acbbf0>]

# %%
plt.plot(x = pd_470_clean[''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.plot(x = pd_470_clean[''])
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ''

# %%
plt.plot(x = pd_470_clean['Timestamp'], y = pd_470_clean['FrameCounter'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plt.plot(x = pd_470_clean['Timestamp'], y = pd_470_clean['FrameCounter'])
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#    3832         scaley=scaley,
#    3833         **({"data": data} if data is not None else {}),
#    3834         **kwargs,
#    3835     )
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\matplotlib\axes\_base.py:232, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     230 for pos_only in "xy":
#     231     if pos_only in kwargs:
# --> 232         raise _api.kwarg_error(inspect.stack()[1].function, pos_only)
#     234 if not args:
#     235     return
#
# TypeError: plot() got an unexpected keyword argument 'x'

# %%
plt.plot(pd_470_clean['Timestamp'], y = pd_470_clean['FrameCounter'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plt.plot(pd_470_clean['Timestamp'], y = pd_470_clean['FrameCounter'])
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#    3832         scaley=scaley,
#    3833         **({"data": data} if data is not None else {}),
#    3834         **kwargs,
#    3835     )
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\matplotlib\axes\_base.py:232, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     230 for pos_only in "xy":
#     231     if pos_only in kwargs:
# --> 232         raise _api.kwarg_error(inspect.stack()[1].function, pos_only)
#     234 if not args:
#     235     return
#
# TypeError: plot() got an unexpected keyword argument 'y'

# %%
# 2/21/25 Photometry Analysis Code (read raw file and graph)

import pandas as pd
import matplotlib.pyplot as plt

filepath_415 = "C:\\Users\\rache\\Desktop\\test_415_2025-02-18T11_35_22.csv"

filepath_470 = "C:\\Users\\rache\\Desktop\\test_470_2025-02-18T11_35_22.csv"


def read_file(filepath_415, filepath_470):
    pd_415 = pd.read_csv(filepath_415)
    pd_470 = pd.read_csv(filepath_470)

    print(pd_415.head())

    print(pd_470.head())

    pd_415_clean = pd_415[['Timestamp', 'Region0G']]
    pd_470_clean = pd_470[['Timestamp', 'Region0G']]


    print(pd_415_clean.head())
    print(pd_470_clean.head())



    return pd_415_clean, pd_470_clean


pd_415_clean, pd_470_clean = read_file(filepath_415, filepath_470)
# Out:
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             2  3107.800544         1            0        1        0       0
# 2             4  3107.820544         1            0        1        0       0
# 3             6  3107.840544         1            0        1        0       0
# 4             8  3107.860544         1            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.055598
# 2       0  0.054875
# 3       0  0.052332
# 4       0  0.051890
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             1  3107.790560         2            0        1        0       0
# 2             3  3107.810560         2            0        1        0       0
# 3             5  3107.830560         2            0        1        0       0
# 4             7  3107.850560         2            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.038322
# 2       0  0.039498
# 3       0  0.037089
# 4       0  0.036743
#      Timestamp  Region0G
# 0  3107.780576  0.003922
# 1  3107.800544  0.055598
# 2  3107.820544  0.054875
# 3  3107.840544  0.052332
# 4  3107.860544  0.051890
#      Timestamp  Region0G
# 0  3107.780576  0.003922
# 1  3107.790560  0.038322
# 2  3107.810560  0.039498
# 3  3107.830560  0.037089
# 4  3107.850560  0.036743

# %%
# 2/21/25 Photometry Analysis Code (read raw file and graph)

import pandas as pd
import matplotlib.pyplot as plt

filepath_415 = "C:\\Users\\rache\\Desktop\\test_415_2025-02-18T11_35_22.csv"

filepath_470 = "C:\\Users\\rache\\Desktop\\test_470_2025-02-18T11_35_22.csv"


def read_file(filepath_415, filepath_470):
    pd_415 = pd.read_csv(filepath_415)
    pd_470 = pd.read_csv(filepath_470)

    print(pd_415.head())

    print(pd_470.head())

    pd_415_clean = pd_415[['Timestamp', 'Region0G']]
    pd_470_clean = pd_470[['Timestamp', 'Region0G']]


    print(pd_415_clean.head())
    print(pd_470_clean.head())



    return pd_415_clean, pd_470_clean


pd_415_clean, pd_470_clean = read_file(filepath_415, filepath_470)

def plot_415_470(pd_415_clean, pd_470_clean):
    fig, ax = plt.subplots()

    ax.plot([pd_415_clean['Region0G'], pd_470_clean['Region0G']])
# Out:
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             2  3107.800544         1            0        1        0       0
# 2             4  3107.820544         1            0        1        0       0
# 3             6  3107.840544         1            0        1        0       0
# 4             8  3107.860544         1            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.055598
# 2       0  0.054875
# 3       0  0.052332
# 4       0  0.051890
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  3107.780576         7            0        1        0       0
# 1             1  3107.790560         2            0        1        0       0
# 2             3  3107.810560         2            0        1        0       0
# 3             5  3107.830560         2            0        1        0       0
# 4             7  3107.850560         2            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.038322
# 2       0  0.039498
# 3       0  0.037089
# 4       0  0.036743
#      Timestamp  Region0G
# 0  3107.780576  0.003922
# 1  3107.800544  0.055598
# 2  3107.820544  0.054875
# 3  3107.840544  0.052332
# 4  3107.860544  0.051890
#      Timestamp  Region0G
# 0  3107.780576  0.003922
# 1  3107.790560  0.038322
# 2  3107.810560  0.039498
# 3  3107.830560  0.037089
# 4  3107.850560  0.036743

# %%
plot_415_470
# Out:
# <function __main__.plot_415_470(pd_415_clean, pd_470_clean)>

# %%
def plot_415_470(pd_415_clean, pd_470_clean):
    fig, ax = plt.subplots()

    ax.plot([pd_415_clean['Region0G'], pd_470_clean['Region0G']])

    plt.show()

# %%
plot_415_470
# Out:
# <function __main__.plot_415_470(pd_415_clean, pd_470_clean)>

# %%
fig, ax = plt.subplots()

ax.plot([pd_415_clean['Region0G'], pd_470_clean['Region0G']])

plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(pd_415_clean['Region0G'])

# %%
fig, ax = plt.subplots()

ax.plot(y = [pd_415_clean['Region0G'], pd_470_clean['Region0G']])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 fig, ax = plt.subplots()
# ----> 3 ax.plot(y = [pd_415_clean['Region0G'], pd_470_clean['Region0G']])
#       5 plt.show()
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File c:\Users\rache\anaconda3\envs\PAML1\Lib\site-packages\matplotlib\axes\_base.py:232, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     230 for pos_only in "xy":
#     231     if pos_only in kwargs:
# --> 232         raise _api.kwarg_error(inspect.stack()[1].function, pos_only)
#     234 if not args:
#     235     return
#
# TypeError: plot() got an unexpected keyword argument 'y'

# %%
fig, ax = plt.subplots()

ax.plot(pd_415_clean['Region0G'])

# %%
fig, ax = plt.subplots()

ax.plot(pd_415_clean['Region0G'])

ax.plot(pd_470_clean['Region0G'])

# %%
filepath_470 = "D:\\Ashna_test\\test_470_2025-02-18T12_15_48.csv"
filepath_415 = "D:\\Ashna_test\\test_415_2025-02-18T12_15_48.csv"

# %%
pd_415_clean, pd_470_clean = read_file(filepath_415, filepath_470)
# Out:
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  5534.215584         7            0        1        0       0
# 1             2  5534.235552         1            0        1        0       0
# 2             4  5534.255552         1            0        1        0       0
# 3             6  5534.275552         1            0        1        0       0
# 4             8  5534.295552         1            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.022295
# 2       0  0.023714
# 3       0  0.023326
# 4       0  0.023072
#    FrameCounter    Timestamp  LedState  Stimulation  Output0  Output1  Input0  \
# 0             0  5534.215584         7            0        1        0       0
# 1             1  5534.225568         2            0        1        0       0
# 2             3  5534.245568         2            0        1        0       0
# 3             5  5534.265568         2            0        1        0       0
# 4             7  5534.285568         2            0        1        0       0
#
#    Input1  Region0G
# 0       0  0.003922
# 1       0  0.019019
# 2       0  0.018624
# 3       0  0.018303
# 4       0  0.020069
#      Timestamp  Region0G
# 0  5534.215584  0.003922
# 1  5534.235552  0.022295
# 2  5534.255552  0.023714
# 3  5534.275552  0.023326
# 4  5534.295552  0.023072
#      Timestamp  Region0G
# 0  5534.215584  0.003922
# 1  5534.225568  0.019019
# 2  5534.245568  0.018624
# 3  5534.265568  0.018303
# 4  5534.285568  0.020069

# %%
def plot_415_470(pd_415_clean, pd_470_clean, timewindow):



    fig, ax = plt.subplots()

    ax.plot(pd_415_clean['Region0G'].iloc[timewindow])
    ax.plot(pd_470_clean['Region0G'].iloc[timewindow])

    plt.show()

# %%
timewindow = [0:1000]
plot_415_470(pd_415_clean, pd_470_clean, timewindow):
# Out:
#   Cell In[37], line 1
#     timewindow = [0:1000]
#                    ^
# SyntaxError: invalid syntax

# %%
timewindow = [0,1000]
plot_415_470(pd_415_clean, pd_470_clean, timewindow):
# Out:
#   Cell In[38], line 2
#     plot_415_470(pd_415_clean, pd_470_clean, timewindow):
#                                                         ^
# SyntaxError: invalid syntax

# %%
timewindow = [0,1000]
plot_415_470(pd_415_clean, pd_470_clean, timewindow)

# %%
def plot_415_470(pd_415_clean, pd_470_clean, time_start, time_stop):



    fig, ax = plt.subplots()

    ax.plot(pd_415_clean['Region0G'].iloc[time_start:time_stop])
    ax.plot(pd_470_clean['Region0G'].iloc[time_start:time_stop])

    plt.show()

# %%
time_start = 0
time_stop = 1000
plot_415_470(pd_415_clean, pd_470_clean, time_start, time_stop)

# %%
def plot_415_470(pd_415_clean, pd_470_clean, time_start, time_stop):



    fig, ax = plt.subplots()

    ax.plot(pd_415_clean['Region0G'].iloc[time_start:time_stop], label = '415')
    ax.plot(pd_470_clean['Region0G'].iloc[time_start:time_stop], label = '470')

    ax.set_xlabel('frames')  # Add an x-label to the Axes.
    ax.set_ylabel('raw fluorescence')  # Add a y-label to the Axes.
    ax.set_title("415 vs 470")  # Add a title to the Axes.
    ax.legend()  # Add a legend.


    plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(pd_415_clean['Region0G'].iloc[time_start:time_stop], label = '415')
ax.plot(pd_470_clean['Region0G'].iloc[time_start:time_stop], label = '470')

ax.set_xlabel('frames')  # Add an x-label to the Axes.
ax.set_ylabel('raw fluorescence')  # Add a y-label to the Axes.
ax.set_title("415 vs 470")  # Add a title to the Axes.
ax.legend()  # Add a legend.


plt.show()

# %%
time_start = 200
time_stop = 600
plot_415_470(pd_415_clean, pd_470_clean, time_start, time_stop)

# %%
def plot_two_traces(trace1, trace2, time_start, time_stop, trace1_label = '415', trace2_label = '470', title = '415 vs 470'):

    fig, ax = plt.subplots()

    ax.plot(trace1.iloc[time_start:time_stop], label = trace1_label)
    ax.plot(trace2.iloc[time_start:time_stop], label = trace2_label)

    ax.set_xlabel('frames')  # Add an x-label to the Axes.
    ax.set_ylabel('raw fluorescence')  # Add a y-label to the Axes.
    ax.set_title(title)  # Add a title to the Axes.
    ax.legend()  # Add a legend.


    plt.show()

# %%
plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 plot
#
# NameError: name 'plot' is not defined

# %%
plot_two_traces(trace1 = pd_415_clean['Region0G'], trace2 = pd_470_clean['Region0G'], time_start = 100, time_stop = 400)
